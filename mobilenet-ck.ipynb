# %%
import numpy as np
import pandas as pd
import cv2
import os
import math
import time
import random
import datetime
import json
from tensorboard import notebook
from sklearn.model_selection import KFold, StratifiedKFold
from PIL import Image
import matplotlib.pyplot as plt
import dlib
import glob
import tensorflow as tf
from tensorflow.keras import Model, Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Concatenate, Dropout, Activation, Add, Input, Dense, Conv2D, Flatten, GlobalAvgPool2D, GlobalMaxPool2D, MaxPooling2D, AvgPool2D, Flatten
from tensorflow.keras.optimizers import Adam, Nadam, RMSprop, SGD
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
#from monitor_training import MonitorSingleTraining
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import optimizers
from multiprocessing import Queue
import pandas as pd
import scikitplot
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.utils import shuffle

# %%
img_path = "../input/ckplus/CK+48"
num_classes = 7
#global total_images = 0
filename_list=["anger", "contempt","disgust", "fear","happy", "sadness", "surprise"]
y_train=[]

# %%
# class label dictionaries
CLASS_LABEL_MAP = {0:"Angry", 1:"Disgust", 2:"Fear", 3:"Happy", 4:"Neutral", 5:"Sad", 6:"Surprise"}
LABEL_CLASS_MAP = {"Angry":0, "Disgust":1, "Fear":2, "Happy":3, "Neutral":4, "Sad":5, "Surprise":6}

# %%
def load_images(filename_list, width =300, height =300, org_dim=False):
    img_array = []
    
    for i in range(len(filename_list)):
        path=os.path.join(img_path,filename_list[i])
        class_num= filename_list[i]
        if org_dim == True:
            for img in os.listdir(path):
                im = load_img(path=os.path.join(path,img), color_mode="grayscale")
                im = np.array(im)
                im = np.repeat(im[...,np.newaxis],3,-1).reshape((im.shape[0],im.shape[1],3))
                total_images +=1
        else:  
            for img in os.listdir(path):
                #im = load_img(os.path.join(path,img), color_mode="grayscale")
                #im = np.array(im)
                #im = np.repeat(im[...,np.newaxis],3,-1).reshape((im.shape[0],im.shape[1],3))
                im = load_img(path=os.path.join(path,img),target_size=(width,height), color_mode="grayscale")
                im = np.repeat(np.array(im)[...,np.newaxis],3,-1).reshape((width,height,3))
                img_array.append(im)
                #y_train.append(class_num)
                #total_images +=1
        
    return np.array(img_array)

# %%
def CLAHE(img,clahe, verbose=False):
    
    equr = clahe.apply(img[:,:,0])
    equg = clahe.apply(img[:,:,1])
    equb = clahe.apply(img[:,:,2])
    equ = np.dstack((equr,equg,equb))
    
    if verbose==True:
        equ_minmax = cv2.normalize(equ, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
        for i in range(0,28709):
            img[i] = img[i]/255.0
        for i in range(0,28709):
            equ[i] = equ[i]/255.0    
        plt.imshow(np.hstack((img,equ,equ_minmax)))
        plt.show()
        
    return equ

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))

# %%
def normalize_data(img_data,params={},verbose=False):
    
    normalized_img_data = []
    # contrast limited adaptive histogram equalization
    clahe_transform = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    for i in range(img_data.shape[0]):
        normalized_img_data.append(CLAHE(np.array(img_data[i]),clahe_transform,verbose))
        
    normalized_img_data = np.array(normalized_img_data,dtype=np.float32)
    
    return normalized_img_data

# %%
img_array_300=load_images(filename_list,300,300)

# %%
img_array_300.shape
# Out:
# (981, 300, 300, 3)

# %%
normalized_img_array_300 = normalize_data(img_array_300)

# %%
normalized_img_array_300.shape
# Out:
# (981, 300, 300, 3)

# %%
opencv_dnn_caffe_model = "../input/modelcaffe/deploy.caffemodel"
opencv_dnn_caffe_prototxt = "../input/modelcaffe/deploy.prototxt.txt"
caffe_net = cv2.dnn.readNetFromCaffe(opencv_dnn_caffe_prototxt, opencv_dnn_caffe_model)

# %%
def face_crop(img_data):
    face_crop_img_data = []
    for i in range(img_data.shape[0]):
        image1=img_data[i]
        image2=img_data[i]
#         print(image1.shape)
        blob = cv2.dnn.blobFromImage(np.float32(image1), 1.0,(300, 300), (104.0, 117.0, 123.0))
        caffe_net.setInput(blob)
        faces = caffe_net.forward()
        w=300
        h=300  
        for j in range(0, faces.shape[2]):
            box = faces[0, 0, j, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            confidence = faces[0, 0, j, 2]
            if startX>300 or startY>300 or endX>300 or endY>300:
                continue
            if endX<startX or endY<startY:
                continue
              # If confidence > 0.5, show box around face
            flag=False
            if (confidence > 0.5):
                image3 = image1[startY:endY, startX:endX]
                #image1=cv2.resize(image1,(300,300))
                if(image3.shape[0]==0 or image3.shape[1]==0):
                    continue
                #print(image3.shape)
                face_crop_img_data.append(image3)
                flag=True
                break
        if(flag==False):
            face_crop_img_data.append(image2)
    #face_crop_img_data = np.array(face_crop_img_data,dtype=np.uint16)
    
    return face_crop_img_data

# %%
face_crop_img_data_300 = face_crop(normalized_img_array_300)

# %%
len(face_crop_img_data_300)
# Out:
# 981

# %%
face_crop_img_data_300 = np.array(face_crop_img_data_300)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """Entry point for launching an IPython kernel.

# %%
face_crop=[]
for i in range(face_crop_img_data_300.shape[0]):
    image1=face_crop_img_data_300[i]
    image1=cv2.resize(image1,(224,224))
    face_crop.append(image1)

# %%
face_crop_array=np.array(face_crop)

# %%
face_crop_array.shape
# Out:
# (981, 224, 224, 3)

# %%
face_crop_array = face_crop_array/255.0

# %% [markdown]
# ## input shuffle and data split

# %%
y_train = np.ones((981,),dtype='int64')

y_train[0:134]=0 #135
y_train[135:188]=1 #54
y_train[189:365]=2 #177
y_train[366:440]=3 #75
y_train[441:647]=4 #207
y_train[648:731]=5 #84
y_train[732:980]=6 #249

# %%
Y_train = to_categorical(y_train, 7)

# %%
#Shuffle the dataset
x,y = shuffle(face_crop_array,Y_train, random_state=2)

# %%
X_train, X_test, Y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=2)

# %%
img_width = X_train.shape[1]
img_height = X_train.shape[2]
img_depth = X_train.shape[3]
num_classes = Y_train.shape[1]

# %%
mobile_net = MobileNet(
    input_shape = (img_width, img_height, img_depth),
    include_top = False,
    weights = "imagenet",
    classes = num_classes
)

x = mobile_net.layers[-14].output
global_pool = GlobalMaxPool2D(name="global_pool")(x)
out = Dense(num_classes, activation="softmax", name="out_layer")(global_pool)

model = Model(inputs=mobile_net.input, outputs=out)
# Out:
# 2022-03-13 10:57:26.630508: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 0s 0us/step
# 17235968/17225924 [==============================] - 0s 0us/step

# %%
for layer in model.layers[:15]:
    layer.trainable = False

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    zca_whitening=False,
)
train_datagen.fit(X_train)

# %%
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.00008,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    min_delta=0.0001,
    factor=0.25,
    patience=4,
    min_lr=1e-7,
    verbose=1,
)

callbacks = [
    early_stopping,
    lr_scheduler,
]

# %%
batch_size = 25
epochs = 40
print("111111111111111111111111111111")
optims = [
    optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07),
    optimizers.Adam(0.01),
]
print("222222222222222222222222222222")
model.compile(
        loss='categorical_crossentropy',
        optimizer=optims[1],
        metrics=['accuracy']
)
print("333333333333333333333333333333")
history = model.fit_generator(
    train_datagen.flow(X_train, Y_train, batch_size=batch_size),
    validation_data=(X_test, y_test),
    steps_per_epoch=len(X_train) / batch_size,
    epochs=epochs,
    callbacks=callbacks,
    use_multiprocessing=True
)
# Out:
# 111111111111111111111111111111
# 222222222222222222222222222222
# 333333333333333333333333333333
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2022-03-13 10:58:32.246167: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/40
# 33/33 [==============================] - 49s 1s/step - loss: 7.1886 - accuracy: 0.1765 - val_loss: 14.6744 - val_accuracy: 0.2162
# Epoch 2/40
# 33/33 [==============================] - 44s 1s/step - loss: 2.5439 - accuracy: 0.2065 - val_loss: 6.4128 - val_accuracy: 0.2162
# Epoch 3/40
# 33/33 [==============================] - 45s 1s/step - loss: 1.9285 - accuracy: 0.2677 - val_loss: 6.3694 - val_accuracy: 0.1554
# Epoch 4/40
# 33/33 [==============================] - 44s 1s/step - loss: 1.7492 - accuracy: 0.3878 - val_loss: 3.8038 - val_accuracy: 0.2297
# Epoch 5/40
# 33/33 [==============================] - 45s 1s/step - loss: 1.3909 - accuracy: 0.5330 - val_loss: 2.1741 - val_accuracy: 0.4595
# Epoch 6/40
# 33/33 [==============================] - 44s 1s/step - loss: 1.1328 - accuracy: 0.6423 - val_loss: 5.9710 - val_accuracy: 0.1892
# Epoch 7/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.8366 - accuracy: 0.7119 - val_loss: 1.6799 - val_accuracy: 0.5608
# Epoch 8/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.6873 - accuracy: 0.7647 - val_loss: 0.8224 - val_accuracy: 0.7905
# Epoch 9/40
# 33/33 [==============================] - 46s 1s/step - loss: 0.6429 - accuracy: 0.7911 - val_loss: 0.8707 - val_accuracy: 0.7568
# Epoch 10/40
# 33/33 [==============================] - 46s 1s/step - loss: 0.4511 - accuracy: 0.8523 - val_loss: 0.6336 - val_accuracy: 0.8108
# Epoch 11/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.4469 - accuracy: 0.8739 - val_loss: 2.4129 - val_accuracy: 0.6419
# Epoch 12/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.3669 - accuracy: 0.8896 - val_loss: 1.0693 - val_accuracy: 0.6689
# Epoch 13/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.3977 - accuracy: 0.8908 - val_loss: 2.8841 - val_accuracy: 0.6419
# Epoch 14/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.3139 - accuracy: 0.8908 - val_loss: 0.3928 - val_accuracy: 0.8446
# Epoch 15/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.3169 - accuracy: 0.9088 - val_loss: 0.6770 - val_accuracy: 0.8108
# Epoch 16/40
# 33/33 [==============================] - 46s 1s/step - loss: 0.3252 - accuracy: 0.9112 - val_loss: 2.3477 - val_accuracy: 0.6554
# Epoch 17/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.2414 - accuracy: 0.9280 - val_loss: 4.6015 - val_accuracy: 0.4932
# Epoch 18/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.2524 - accuracy: 0.9196 - val_loss: 3.0524 - val_accuracy: 0.4324
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# Epoch 19/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.1277 - accuracy: 0.9616 - val_loss: 1.0788 - val_accuracy: 0.7635
# Epoch 20/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0889 - accuracy: 0.9772 - val_loss: 0.4141 - val_accuracy: 0.8581
# Epoch 21/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.0708 - accuracy: 0.9820 - val_loss: 0.2911 - val_accuracy: 0.8919
# Epoch 22/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0646 - accuracy: 0.9772 - val_loss: 0.0745 - val_accuracy: 0.9797
# Epoch 23/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.0712 - accuracy: 0.9784 - val_loss: 0.1110 - val_accuracy: 0.9595
# Epoch 24/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0502 - accuracy: 0.9868 - val_loss: 0.0352 - val_accuracy: 0.9865
# Epoch 25/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.0670 - accuracy: 0.9808 - val_loss: 0.0639 - val_accuracy: 0.9797
# Epoch 26/40
# 33/33 [==============================] - 44s 1s/step - loss: 0.0457 - accuracy: 0.9880 - val_loss: 0.0456 - val_accuracy: 0.9865
# Epoch 27/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0498 - accuracy: 0.9844 - val_loss: 0.0310 - val_accuracy: 0.9797
# Epoch 28/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0529 - accuracy: 0.9832 - val_loss: 0.0725 - val_accuracy: 0.9865
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# Epoch 29/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0452 - accuracy: 0.9916 - val_loss: 0.0480 - val_accuracy: 0.9865
# Epoch 30/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0344 - accuracy: 0.9892 - val_loss: 0.0397 - val_accuracy: 0.9865
# Epoch 31/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0375 - accuracy: 0.9868 - val_loss: 0.0364 - val_accuracy: 0.9865
# Epoch 32/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0332 - accuracy: 0.9868 - val_loss: 0.0414 - val_accuracy: 0.9865
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# Epoch 33/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0294 - accuracy: 0.9916 - val_loss: 0.0403 - val_accuracy: 0.9865
# Epoch 34/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0315 - accuracy: 0.9880 - val_loss: 0.0428 - val_accuracy: 0.9865
# Epoch 35/40
# 33/33 [==============================] - 45s 1s/step - loss: 0.0266 - accuracy: 0.9892 - val_loss: 0.0432 - val_accuracy: 0.9865
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test Loss: 0.03517899289727211
# Test accuracy: 0.9864864945411682

# %%
model.save("model_mobilenet.h5")

# %%
np.random.seed(42)
fear_imgs = np.random.choice(np.where(y_test[:, LABEL_CLASS_MAP["Fear"]]==1)[0], size=9, replace=False)
angry_imgs = np.random.choice(np.where(y_test[:, LABEL_CLASS_MAP["Angry"]]==1)[0], size=9, replace=False)

fig = plt.figure(1, (18, 4))

for i, (fear_idx, angry_idx) in enumerate(zip(fear_imgs, angry_imgs)):
        sample_img = X_test[fear_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = CLASS_LABEL_MAP[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = plt.subplot(2, 9, i+1)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:fear, p:{pred}")

        sample_img = X_test[angry_idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = CLASS_LABEL_MAP[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = plt.subplot(2, 9, i+10)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"t:angry, p:{pred}")

        plt.tight_layout()

# %%
yhat_test = np.argmax(model.predict(X_test), axis=1)
ytest_ = np.argmax(y_test, axis=1)

# %%
def plot_miss_classified(emotion):
    miss_happy_indices = np.where((ytest_ != yhat_test) & (ytest_==LABEL_CLASS_MAP[emotion]))[0]
    print(f"total {len(miss_happy_indices)} miss labels out of {len(np.where(ytest_==LABEL_CLASS_MAP[emotion])[0])} for emotion {emotion}")

    cols = 15
    rows = math.ceil(len(miss_happy_indices) / cols)
    fig = plt.figure(1, (20, rows * 2))

    for i,idx in enumerate(miss_happy_indices):
        sample_img = X_test[idx,:,:,:]
        sample_img = sample_img.reshape(1,*sample_img.shape)
        pred = CLASS_LABEL_MAP[np.argmax(model.predict(sample_img), axis=1)[0]]

        ax = plt.subplot(rows,cols,i+1)
        ax.imshow(sample_img[0,:,:,0], cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"p:{pred}")

# %%
plot_miss_classified(emotion="Happy")
# Out:
# total 0 miss labels out of 10 for emotion Happy

# %%
plot_miss_classified(emotion="Fear")
# Out:
# total 0 miss labels out of 32 for emotion Fear

# %%
plot_miss_classified(emotion="Angry")
# Out:
# total 1 miss labels out of 20 for emotion Angry

# %%
plot_miss_classified(emotion="Neutral")
# Out:
# total 0 miss labels out of 23 for emotion Neutral

# %%
plot_miss_classified(emotion="Disgust")
# Out:
# total 0 miss labels out of 7 for emotion Disgust

# %%
plot_miss_classified(emotion="Surprise")
# Out:
# total 0 miss labels out of 47 for emotion Surprise

# %%
plot_miss_classified(emotion="Sad")
# Out:
# total 1 miss labels out of 9 for emotion Sad
